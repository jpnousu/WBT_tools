# %%
from whitebox_workflows import WbEnvironment
from whitebox_workflows import download_sample_data, show, WbEnvironment
from whitebox_workflows import WbPalette
wbe = WbEnvironment()
wbe.working_directory = r'/Users/jpnousu/WBT_data'

# %%
#dem_file = r'/Users/jpnousu/WBT_data/pallas_16/korkeusmalli_16m_culverts_water_no_deps.tif'
dem_file = r'/Users/jpnousu/SpaFHy_RUNS/krycklan/gis/25m_0case/orig_dem.asc'
dem = wbe.read_raster(dem_file)

# %%
show(
    dem,    
    figsize=(21,15),
    skip=2,
    plot_as_surface=True, 
    vert_exaggeration = 1.,
    colorbar_kwargs={'location': "right",  'shrink': 0.5, 'label': 'Elevation (m)', 'pad' : 0.1},
    cmap=WbPalette.HighRelief,
    shade=True,
    linewidth=0.0, 
    rcount=300, # default is 50 rows and columns for grid
    ccount=300,
    antialiased=False
)
# Out:
# <Axes3D: xlabel='X', ylabel='Y', zlabel='Z'>
